# %%
from sf_class import *

# %%
object_to_fit='1987A_1987-09-09_00-00-00_IUE_IUE_SUSPECT.dat'

# %%
this_supernova = supernova(object_to_fit)

# %%
this_supernova.superfit()
# Out:
# Running optimization for spectrum file: 1987A_1987-09-09_00-00-00_IUE_IUE_SUSPECT with resolution = 10 Å
# Superfit started
# Runtime:  40.67s

# %%
this_supernova.plot()

# %%
this_supernova.sg_error()

# %%
object_to_fit = 'ZTF18abokyfk_20180925_P60_v1.ascii'

# %%
this_other_supernova = supernova(object_to_fit)

# %%
this_other_supernova.superfit()
# Out:
# Running optimization for spectrum file: ZTF18abokyfk_20180925_P60_v1 with resolution = 10 Å
# Superfit failed at 10 Å. Retrying for resolution = 30 Å
# Superfit started
# Runtime:  19.69s
# ''

# %%
this_other_supernova.sg_error()
