# %%
#Make the json file into the first argument
import sys
sys.argv[1] = 'parameters.json'
from supyfit.sf_class import *

# %%
from supyfit.params import Parameters
Parameters = Parameters(data)

# %%
this_supernova = Superfit()

# %% [markdown]
# # Before the fit

# %%
this_supernova.plot()

# %%
this_supernova.mask_galaxy_lines()

# %%
#this_supernova.mask_gal_lines_and_telluric()

# %%
this_supernova.sg_error()

# %%
this_supernova.mask_telluric()

# %%
this_supernova.name
# Out:
# 'SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS.flm'

# %% [markdown]
# # The Superfit

# %%
this_supernova.superfit()
# Out:
# Running optimization for spectrum file: SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS with resolution = 10 Å
# Supyfit started
# Runtime:  7.08s

# %%
#this_supernova.any_result(2)

# %%
this_supernova.results
# Out:
#                                             SPECTRUM GALAXY  \
# 0  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...     S0
# 1  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...     S0
# 2  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...    SB2
# 3  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...    SB5
#
#                                            SN  CONST_SN  CONST_GAL      Z  \
# 0           Ic/1994I/KAST phase-band : -2.57B  0.416672   0.106685  0.127
# 1     Ia-norm/2009Y/WFCCD phase-band : 12.36B  0.298528   0.672471  0.127
# 2       Ic-BL/1998bw/DFOSC phase-band : 12.0B  0.684189   0.141328  0.127
# 3  Ic-BL/1998bw/EFOSC2-3.6 phase-band : 20.0B  1.325954   0.309988  0.127
#
#    A_v  Phase Band  Frac(SN)  Frac(gal)  CHI2/dof  CHI2/dof2
# 0 -2.0  -2.57    B  0.965610   0.034390  6.385532   0.009809
# 1 -1.2  12.36    B  0.615428   0.384572  5.793342   0.009954
# 2 -1.2  12.00    B  0.904592   0.095408  6.567141   0.010661
# 3  1.6  20.00    B  0.560103   0.439897  6.792656   0.010816

# %%
for i in range(4):

    this_supernova.any_result(i)

# %% [markdown]
# ### Versions

# %%
import numpy
print('numpy version: '+numpy.__version__)
import scipy
print('scipy version: '+scipy.__version__)
import matplotlib
print('matplotlib version: '+matplotlib.__version__)
import astropy
print('astropy version: '+astropy.__version__)
import pandas
print('Pandas version: ' +pandas.__version__)
import PyAstronomy
print('PyAstronomy version: '+PyAstronomy.__version__)
import json
print('json version: '+json.__version__)
import sys
print("Python version: ")
print (sys.version)
# Out:
# numpy version: 1.20.3
# scipy version: 1.7.1
# matplotlib version: 3.4.3
# astropy version: 4.3.1
# Pandas version: 1.3.4
# PyAstronomy version: 0.17.1
# json version: 2.0.9
# Python version:
# 3.9.7 (default, Sep 16 2021, 08:50:36)
# [Clang 10.0.0 ]

# %% [markdown]
# ### Phase info

# %%
import pandas as pd


met = glob.glob('**/mjd**')[0]
metadata  = pd.read_csv(met)
band_peak = np.array(metadata['band_peak'])


V,B,g,R,r,unknown =0,0,0,0,0,0

for i in band_peak:
    if str(i) == 'V':
        V+=1
    elif str(i) == 'B':
        B+=1
    elif str(i) == 'g':
        g+=1
    elif str(i) == 'R':
        R+=1
    elif str(i) == 'r':
        r+=1
    elif str(i) == band_peak[-2]:
        unknown+=1  
    else:
        print(i)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

count = np.array([V,B,g,R,r,unknown])
x = np.array(['V','B','g','R','r','unknown'])

plt.bar(x, count , alpha=0.5)
plt.xticks(x, x)
plt.ylabel('Occurance')
plt.title('Band Usage')
# Out:
# Text(0.5, 1.0, 'Band Usage')

# %%
count
# Out:
# array([ 13, 114,  14,   8,   8,  33])
