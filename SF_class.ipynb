# %%
from sf_class import *

# %%
this_supernova = superfit_class(object_to_fit)

# %% [markdown]
# # Before the fit

# %%
this_supernova.plot()

# %%
this_supernova.mask_galaxy_lines()

# %%
#this_supernova.mask_gal_lines_and_telluric()

# %%
this_supernova.sg_error()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
this_supernova.linear_error()

# %% [markdown]
# # The Superfit

# %%
this_supernova.superfit()
# Out:
# Running optimization for spectrum file: SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS with resolution = 10 Å
# Superfit started
# /anaconda3/lib/python3.7/site-packages/scipy/stats/_binned_statistic.py:607: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = result[core]
# /anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# Runtime:  15.88s

# %%
this_supernova.results()
# Out:
#                                          OBJECT GALAXY  \
# 0  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 1  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS    SB5
# 2  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 3  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     Sc
# 4  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
#
#                                      SN  CONST_SN  CONST_GAL      Z  A_v  \
# 0     Ic/1994I/KAST phase-band : -2.57B  0.409524   0.121502  0.127 -2.0
# 1   Ic-BL/2002ap/KAST phase-band : 5.0B  0.592782   0.371530  0.127  0.0
# 2      Ib/2008D/KAST phase-band : -5.0B  2.630791   0.012538  0.127  2.0
# 3    Ic/1994I/BC-Ekar phase-band : 2.0B  0.637319   0.390525  0.127 -0.2
# 4  Ic-BL/1998bw/DFOSC phase-band : 2.0B  0.410608   0.343266  0.127 -1.4
#
#    Frac(SN)  Frac(gal)       CHI2  CHI2/dof  CHI2/dof2 Band  Phase
# 0  0.960973   0.039027  2660.4570  4.037112   0.006126    B  -2.57
# 1  0.662547   0.337453  4110.0024  6.442010   0.010097    B   5.00
# 2  0.978256   0.021744  4032.7380  6.514924   0.010525    B  -5.00
# 3  0.644375   0.355625  4044.3413  6.684862   0.011049    B   2.00
# 4  0.845106   0.154894  4262.7120  6.864270   0.011054    B   2.00

# %%
this_supernova.top_result()
# Out:
# OBJECT       SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS
# GALAXY                                                 S0
# SN                      Ic/1994I/KAST phase-band : -2.57B
# CONST_SN                                         0.409524
# CONST_GAL                                        0.121502
# Z                                                   0.127
# A_v                                                    -2
# Frac(SN)                                         0.960973
# Frac(gal)                                       0.0390274
# CHI2                                              2660.46
# CHI2/dof                                          4.03711
# CHI2/dof2                                      0.00612612
# Band                                                    B
# Phase                                               -2.57
# Name: 0, dtype: object

# %% [markdown]
# ### Versions

# %%
import numpy
print('numpy version: '+numpy.__version__)
import scipy
print('scipy version: '+scipy.__version__)
import matplotlib
print('matplotlib version: '+matplotlib.__version__)
import astropy
print('astropy version: '+astropy.__version__)
import pandas
print('Pandas version: ' +pandas.__version__)
import PyAstronomy
print('PyAstronomy version: '+PyAstronomy.__version__)
import json
print('json version: '+json.__version__)
import sys
print("Python version: ")
print (sys.version)

# %%
import pandas as pd

# %%
metadata  = pd.read_csv('mjd_of_maximum_brightness.csv')
band_peak = np.array(metadata['band_peak'])

# %%
V,B,g,R,r,unknown,U,u =0,0,0,0,0,0,0,0

for i in band_peak:
    if str(i) == 'V':
        V+=1
    elif str(i) == 'B':
        B+=1
    elif str(i) == 'g':
        g+=1
    elif str(i) == 'R':
        R+=1
    elif str(i) == 'r':
        r+=1
    elif str(i) == band_peak[-2]:
        unknown+=1
    elif str(i) == 'U':
        U+=1
    elif str(i) == 'u':
        u+=1       
    else:
        print(i)

# %%
V,B,g,R,r,unknown,U,u
