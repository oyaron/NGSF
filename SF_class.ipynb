# %%
#Make the json file into the first argument
import sys
sys.argv[1] = 'parameters.json'
from supyfit.sf_class import *
# Out:
# /home/sam/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
from supyfit.params import Parameters
Parameters = Parameters(data)

# %%
this_supernova = Superfit()

# %% [markdown]
# # Before the fit

# %%
this_supernova.plot()

# %%
this_supernova.mask_galaxy_lines()

# %%
#this_supernova.mask_gal_lines_and_telluric()

# %%
this_supernova.sg_error()

# %%
this_supernova.mask_telluric()

# %%
this_supernova.name
# Out:
# 'SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS.flm'

# %% [markdown]
# # The Superfit

# %%
this_supernova.superfit()
# Out:
# Running optimization for spectrum file: SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS with resolution = 10 Å
# Supyfit started
# Runtime:  13.20s

# %%
#this_supernova.any_result(2)

# %%
this_supernova.results()
# Out:
#                                             SPECTRUM GALAXY  \
# 0  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...     S0
# 1  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...    SB2
# 2  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...    SB5
# 3  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...     S0
# 4  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...    SB5
# 5  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS_b...    SB5
#
#                                            SN  CONST_SN  CONST_GAL      Z  \
# 0           Ic/1994I/KAST phase-band : -2.57B  0.415407   0.098116  0.127
# 1       Ic-BL/1998bw/DFOSC phase-band : 12.0B  0.675496   0.142187  0.127
# 2  Ic-BL/1998bw/EFOSC2-3.6 phase-band : 20.0B  1.302232   0.313257  0.127
# 3     Ia-norm/2009Y/WFCCD phase-band : 12.36B  0.305018   0.649830  0.127
# 4        Ic-BL/1998bw/DFOSC phase-band : 7.0B  0.549874   0.299452  0.127
# 5      Ic-BL/1998bw/DFOSC phase-band : 46.24B  0.812917   0.343553  0.127
#
#    A_v  Phase Band  Frac(SN)  Frac(gal)  CHI2/dof  CHI2/dof2
# 0 -2.0  -2.57    B  0.968182   0.031818  5.300340   0.008180
# 1 -1.2  12.00    B  0.902941   0.097059  5.589958   0.009119
# 2  1.6  20.00    B  0.552998   0.447002  5.991344   0.009586
# 3 -1.2  12.36    B  0.628687   0.371313  5.718534   0.009894
# 4 -1.4   7.00    B  0.841632   0.158368  6.230191   0.010163
# 5  0.0  46.24    B  0.696958   0.303042  6.785714   0.011052

# %%
for i in range(4):

    this_supernova.any_result(i)

# %% [markdown]
# ### Versions

# %%
import numpy
print('numpy version: '+numpy.__version__)
import scipy
print('scipy version: '+scipy.__version__)
import matplotlib
print('matplotlib version: '+matplotlib.__version__)
import astropy
print('astropy version: '+astropy.__version__)
import pandas
print('Pandas version: ' +pandas.__version__)
import PyAstronomy
print('PyAstronomy version: '+PyAstronomy.__version__)
import json
print('json version: '+json.__version__)
import sys
print("Python version: ")
print (sys.version)
# Out:
# numpy version: 1.21.3
# scipy version: 1.2.1
# matplotlib version: 3.4.3
# astropy version: 4.3.1
# Pandas version: 1.3.4
# PyAstronomy version: 0.15.1
# json version: 2.0.9
# Python version:
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %% [markdown]
# ### Phase info

# %%
import pandas as pd


met = glob.glob('**/mjd**')[0]
metadata  = pd.read_csv(met)
band_peak = np.array(metadata['band_peak'])


V,B,g,R,r,unknown =0,0,0,0,0,0

for i in band_peak:
    if str(i) == 'V':
        V+=1
    elif str(i) == 'B':
        B+=1
    elif str(i) == 'g':
        g+=1
    elif str(i) == 'R':
        R+=1
    elif str(i) == 'r':
        r+=1
    elif str(i) == band_peak[-2]:
        unknown+=1  
    else:
        print(i)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

count = np.array([V,B,g,R,r,unknown])
x = np.array(['V','B','g','R','r','unknown'])

plt.bar(x, count , alpha=0.5)
plt.xticks(x, x)
plt.ylabel('Occurance')
plt.title('Band Usage')
# Out:
# Text(0.5, 1.0, 'Band Usage')

# %%
count
# Out:
# array([ 13, 114,  14,   8,   8,  33])
