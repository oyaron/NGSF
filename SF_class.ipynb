# %%
from sf_class import *

# %%
this_supernova = superfit_class(object_to_fit)

# %% [markdown]
# # Before the fit

# %%
this_supernova.plot()

# %%
this_supernova.mask_galaxy_lines()

# %%
#this_supernova.mask_gal_lines_and_telluric()

# %%
this_supernova.sg_error()

# %%
this_supernova.linear_error()

# %% [markdown]
# # The Superfit

# %%
this_supernova.superfit()
# Out:
# Running optimization for spectrum file: SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS with resolution = 10 Å
# Superfit started
# Runtime:  6.13s

# %%
this_supernova.results()
# Out:
#                                          OBJECT GALAXY  \
# 0  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 1  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS    SB5
# 2  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     Sc
# 3  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 4  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     Sc
#
#                                     SN  CONST_SN  CONST_GAL      Z  A_v  \
# 0    Ic/1994I/KAST phase-band : -2.57B  0.414212   0.128019  0.127 -2.0
# 1  Ic-BL/2002ap/KAST phase-band : 5.0B  0.568943   0.363202  0.127 -0.2
# 2   Ic/1994I/BC-Ekar phase-band : 2.0B  0.597009   0.384102  0.127 -0.4
# 3     Ib/2008D/KAST phase-band : -5.0B  2.622301   0.015728  0.127  2.0
# 4    Ib/2007C/LRIS phase-band : -1.31B  1.854054   0.322439  0.127  2.0
#
#    Frac(SN)  Frac(gal)       CHI2  CHI2/dof  CHI2/dof2 Band  Phase
# 0  0.958782   0.041218  2629.2903  3.989818   0.006054    B  -2.57
# 1  0.690070   0.309930  3949.2550  6.180368   0.009672    B   5.00
# 2  0.671805   0.328195  3694.1213  6.105986   0.010093    B   2.00
# 3  0.972874   0.027126  4308.0796  6.926173   0.011135    B  -5.00
# 4  0.471810   0.528190  4974.6445  7.748668   0.012070    B  -1.31

# %%
this_supernova.top_result()
# Out:
# OBJECT       SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS
# GALAXY                                                 S0
# SN                      Ic/1994I/KAST phase-band : -2.57B
# CONST_SN                                         0.414212
# CONST_GAL                                        0.128019
# Z                                                   0.127
# A_v                                                    -2
# Frac(SN)                                         0.958782
# Frac(gal)                                       0.0412183
# CHI2                                              2629.29
# CHI2/dof                                          3.98982
# CHI2/dof2                                      0.00605435
# Band                                                    B
# Phase                                               -2.57
# Name: 0, dtype: object

# %%
pd.read_csv('SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS.csv')
# Out:
#                                          OBJECT GALAXY  \
# 0  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 1  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS    SB5
# 2  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     Sc
# 3  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 4  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     Sc
#
#                                     SN  CONST_SN  CONST_GAL      Z  A_v  \
# 0    Ic/1994I/KAST phase-band : -2.57B  0.414291   0.122406  0.127 -2.0
# 1  Ic-BL/2002ap/KAST phase-band : 5.0B  0.606199   0.369165  0.127  0.0
# 2   Ic/1994I/BC-Ekar phase-band : 2.0B  0.629487   0.396242  0.127 -0.2
# 3     Ib/2008D/KAST phase-band : -5.0B  2.617986   0.013182  0.127  2.0
# 4    Ib/2007C/LRIS phase-band : -1.31B  1.815958   0.333557  0.127  2.0
#
#    Frac(SN)  Frac(gal)       CHI2  CHI2/dof  CHI2/dof2 Band  Phase
# 0  0.960514   0.039487  2439.5103  3.701837   0.005617    B  -2.57
# 1  0.663257   0.336743  3887.4160  6.083593   0.009520    B   5.00
# 2  0.637548   0.362452  3583.2847  5.922784   0.009790    B   2.00
# 3  0.977100   0.022900  4263.0986  6.853857   0.011019    B  -5.00
# 4  0.457871   0.542129  4902.0083  7.635527   0.011893    B  -1.31

# %% [markdown]
# ### Versions

# %%
import numpy
print('numpy version: '+numpy.__version__)
import scipy
print('scipy version: '+scipy.__version__)
import matplotlib
print('matplotlib version: '+matplotlib.__version__)
import astropy
print('astropy version: '+astropy.__version__)
import pandas
print('Pandas version: ' +pandas.__version__)
import PyAstronomy
print('PyAstronomy version: '+PyAstronomy.__version__)
import json
print('json version: '+json.__version__)
import sys
print("Python version: ")
print (sys.version)
# Out:
# numpy version: 1.21.2
# scipy version: 1.7.1
# matplotlib version: 3.0.2
# astropy version: 3.1
# Pandas version: 0.23.4
# PyAstronomy version: 0.13.0
# json version: 2.0.9
# Python version:
# 3.7.1 (default, Dec 14 2018, 13:28:58)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# ### Phase info

# %%
import pandas as pd

metadata  = pd.read_csv('mjd_of_maximum_brightness.csv')
band_peak = np.array(metadata['band_peak'])


V,B,g,R,r,unknown,U,u =0,0,0,0,0,0,0,0

for i in band_peak:
    if str(i) == 'V':
        V+=1
    elif str(i) == 'B':
        B+=1
    elif str(i) == 'g':
        g+=1
    elif str(i) == 'R':
        R+=1
    elif str(i) == 'r':
        r+=1
    elif str(i) == band_peak[-2]:
        unknown+=1
    elif str(i) == 'U':
        U+=1
    elif str(i) == 'u':
        u+=1       
    else:
        print(i)

# %%
V,B,g,R,r,unknown,U,u
# Out:
# (13, 114, 14, 8, 7, 33, 1, 1)
