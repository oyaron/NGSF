# %%
from sf_class import *
# Out:
# /home/sam/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
this_supernova = superfit_class(object_to_fit)

# %% [markdown]
# # Before the fit

# %%
this_supernova.plot()

# %%
this_supernova.mask_galaxy_lines()

# %%
#this_supernova.mask_gal_lines_and_telluric()

# %%
this_supernova.sg_error()

# %%
this_supernova.linear_error()

# %% [markdown]
# # The Superfit

# %%
this_supernova.superfit()
# Out:
# Running optimization for spectrum file: SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS with resolution = 10 Å
# Superfit started
# Runtime:  13.27s

# %%
this_supernova.results()
# Out:
#                                          OBJECT GALAXY  \
# 0  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 1  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS     S0
# 2  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS    SB5
# 3  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS    SB5
# 4  SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS    SB5
#
#                                            SN  CONST_SN  CONST_GAL      Z  \
# 0           Ic/1994I/KAST phase-band : -2.57B  0.414291   0.122406  0.127
# 1     Ia-norm/2009Y/WFCCD phase-band : 12.36B  0.300130   0.679340  0.127
# 2       Ic-BL/1998bw/DFOSC phase-band : 12.0B  0.717030   0.283118  0.127
# 3  Ic-BL/1998bw/EFOSC2-3.6 phase-band : 20.0B  1.355084   0.298212  0.127
# 4      Ic-BL/1998bw/DFOSC phase-band : 46.24B  0.824830   0.347223  0.127
#
#    A_v  Phase Band  Frac(SN)  Frac(gal)  CHI2/dof  CHI2/dof2
# 0 -2.0  -2.57    B  0.960514   0.039487  3.701837   0.005617
# 1 -1.2  12.36    B  0.614442   0.385558  4.116747   0.006989
# 2 -0.8  12.00    B  0.816453   0.183547  4.369890   0.007003
# 3  1.6  20.00    B  0.574880   0.425120  4.873283   0.007662
# 4  0.0  46.24    B  0.697786   0.302214  5.583837   0.008934

# %%
this_supernova.top_result()
# Out:
# OBJECT       SN2021urb_2021-08-06_00-00-00_Keck1_LRIS_TNS
# GALAXY                                                 S0
# SN                      Ic/1994I/KAST phase-band : -2.57B
# CONST_SN                                         0.414291
# CONST_GAL                                        0.122406
# Z                                                   0.127
# A_v                                                  -2.0
# Phase                                               -2.57
# Band                                                    B
# Frac(SN)                                         0.960514
# Frac(gal)                                        0.039487
# CHI2/dof                                         3.701837
# CHI2/dof2                                        0.005617
# Name: 0, dtype: object

# %% [markdown]
# ### Versions

# %%
import numpy
print('numpy version: '+numpy.__version__)
import scipy
print('scipy version: '+scipy.__version__)
import matplotlib
print('matplotlib version: '+matplotlib.__version__)
import astropy
print('astropy version: '+astropy.__version__)
import pandas
print('Pandas version: ' +pandas.__version__)
import PyAstronomy
print('PyAstronomy version: '+PyAstronomy.__version__)
import json
print('json version: '+json.__version__)
import sys
print("Python version: ")
print (sys.version)
# Out:
# numpy version: 1.21.3
# scipy version: 1.2.1
# matplotlib version: 3.4.3
# astropy version: 4.3.1
# Pandas version: 1.3.4
# PyAstronomy version: 0.15.1
# json version: 2.0.9
# Python version:
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %% [markdown]
# ### Phase info

# %%
import pandas as pd

metadata  = pd.read_csv('mjd_of_maximum_brightness.csv')
band_peak = np.array(metadata['band_peak'])


V,B,g,R,r,unknown =0,0,0,0,0,0

for i in band_peak:
    if str(i) == 'V':
        V+=1
    elif str(i) == 'B':
        B+=1
    elif str(i) == 'g':
        g+=1
    elif str(i) == 'R':
        R+=1
    elif str(i) == 'r':
        r+=1
    elif str(i) == band_peak[-2]:
        unknown+=1  
    else:
        print(i)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

count = np.array([V,B,g,R,r,unknown])
x = np.array(['V','B','g','R','r','unknown'])

plt.bar(x, count , alpha=0.5)
plt.xticks(x, x)
plt.ylabel('Occurance')
plt.title('Band Usage')
# Out:
# Text(0.5, 1.0, 'Band Usage')

# %%
count
# Out:
# array([ 13, 114,  14,   8,   8,  33])
